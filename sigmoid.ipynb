# %% [markdown]
# <a href="https://colab.research.google.com/github/misioskyyy/codingGigants/blob/main/sigmoid.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

def sigmoid(x):
  return 1/(1+np.exp(-x))

# Generujemy wartości x dla wykresu
x = np.linspace(-10, 10, 100)

# Obliczamy wartości y za pomocą funkcji sigmoid
y = sigmoid(x)

# Rysujemy wykres
plt.plot(x, y)
plt.xlabel("x")
plt.ylabel("sigmoid(x)")
plt.title("Wykres funkcji sigmoid")
plt.grid(True)
plt.show()

# %%
# napisz program generujący 200 punktów i przydzielający je do 2 klas.

## Podziel punkty na zbiór testowy i uczący
## narysuj wykres  punktów należący do zbioru uczącego
## przyporżadkuj klasy punktom ze zbioru testowego
## sprawdz cyz program dokonał prawidłowej prognozy
import numpy as np
import matplotlib.pyplot as plt

from sklearn.datasets import make_classification
from sklearn.linear_model import LogisticRegression

import random

X, Y = make_classification(n_samples=200, n_features=2, n_classes=2, n_redundant=0, random_state=42)

# dane treningowe
# dane testowe
